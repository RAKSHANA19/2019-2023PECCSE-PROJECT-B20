# %% [markdown]
# # Module 6 : XGBRegressor

# %%
#import library packages
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load given dataset
data = yf.download('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = data.dropna()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
del df['Adj Close']

# %%
df.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   73449600

# %%
df.tail()
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2023-03-24  158.860001  160.339996  157.850006  160.250000  59196500
# 2023-03-27  159.940002  160.770004  157.869995  158.279999  52390300
# 2023-03-28  157.970001  158.490005  155.979996  157.649994  45992200
# 2023-03-29  159.369995  161.050003  159.350006  160.770004  51305700
# 2023-03-30  161.529999  162.470001  161.270004  162.360001  49456700

# %%
#preprocessing, split test and dataset, split response variable
X = df.drop(labels='Close', axis=1)
#Response variable
y = df.loc[:,'Close']

# %%
#Splitting for train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
print("Number of training dataset: ", len(X_train))
print("Number of test dataset: ", len(X_test))
print("Total number of dataset: ", len(X_train)+len(X_test))
# Out:
# Number of training dataset:  7464
# Number of test dataset:  3200
# Total number of dataset:  10664

# %% [markdown]
# ##### Implementing XGBRegressor Algo

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,explained_variance_score,median_absolute_error

# %% [markdown]
# Training

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)
predicted = xgb.predict(X_test)

# %% [markdown]
# Finding mean_absolute_error

# %%
MAE= (mean_absolute_error(y_test,predicted))
print('MEAN ABSOLUTE ERROR VALUE IS :',MAE)
# Out:
# MEAN ABSOLUTE ERROR VALUE IS : 0.14816079205600544

# %% [markdown]
# Finding mean_squared_error

# %%
MSE=(mean_squared_error(y_test,predicted))
print('MEAN SQUARED ERROR VALUE IS :',MSE)
# Out:
# MEAN SQUARED ERROR VALUE IS : 0.20836214168014996

# %% [markdown]
# Finding median_absolute_error

# %%
MedianAE=(median_absolute_error(y_test,predicted))
print('MEDIAN ABSOLUTE ERROR VALUE IS :',MedianAE)
# Out:
# MEDIAN ABSOLUTE ERROR VALUE IS : 0.01507580280303955

# %% [markdown]
# Finding r2_score

# %%
R2=(r2_score(y_test,predicted))
print('R2_SCORE VALUE IS :',R2*100)
# Out:
# R2_SCORE VALUE IS : 99.98407953820042

# %%
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
